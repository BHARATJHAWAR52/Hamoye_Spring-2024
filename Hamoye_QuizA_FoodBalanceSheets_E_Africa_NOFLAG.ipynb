# %% [markdown]
# <a href="https://colab.research.google.com/github/BHARATJHAWAR52/Hamoye_Spring-2024/blob/main/Hamoye_QuizA_FoodBalanceSheets_E_Africa_NOFLAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
food=pd.read_csv("/content/drive/MyDrive/HAMOYE SPRING'24/FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="latin-1")

# %%
food
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
food.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
food.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
data_2017 = food['Y2017']
mean_2017 = data_2017.mean()
std_dev_2017 = data_2017.std()
print(f"mean_2017={mean_2017} std_dev_2017={std_dev_2017}")
# Out:
# mean_2017=140.9177648602722 std_dev_2017=1671.8623590567995

# %%
selected_data1= food[['Area', 'Y2017']]
sum_2017_by_area = selected_data1.groupby('Area')['Y2017'].sum()
area_highest_sum_2017 = sum_2017_by_area.idxmax()
area_highest_sum_2017
# Out:
# 'Nigeria'

# %%
total_unique_countries = food['Area'].nunique()
total_unique_countries
# Out:
# 49

# %%
element_data_select = food[['Element', 'Y2017']]
sum_2017_by_element = element_data_select.groupby('Element')['Y2017'].sum()
sum_processing_2017 = sum_2017_by_element.loc['Processing']
sum_processing_2017
# Out:
# 292836.0

# %%
madagascar_protein_data_2015 = food[(food['Area'] == 'Madagascar') & (food['Element'] == 'Protein supply quantity (g/capita/day)')]
total_protein_supply_2015 = madagascar_protein_data_2015['Y2015'].sum()
total_protein_supply_2015
# Out:
# 173.04999999999998

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
x1=y[1][1]
x2=y[2][-1]
x3=y[1][-1]
x4=y[1][-2]
print(f"x1={x1},x2={x2},x3={x3},x4={x4}")
# Out:
# x1=8,x2=9,x3=8,x4=7

# %%
unique_items = food['Item'].unique()
unique_items
# Out:
# array(['Population', 'Grand Total', 'Vegetal Products', 'Animal Products',
#        'Cereals - Excluding Beer', 'Wheat and products',
#        'Rice and products', 'Barley and products', 'Maize and products',
#        'Rye and products', 'Oats', 'Millet and products',
#        'Sorghum and products', 'Cereals, Other', 'Starchy Roots',
#        'Cassava and products', 'Potatoes and products', 'Sweet potatoes',
#        'Yams', 'Roots, Other', 'Sugar Crops', 'Sugar cane', 'Sugar beet',
#        'Sugar & Sweeteners', 'Sugar (Raw Equivalent)',
#        'Sweeteners, Other', 'Honey', 'Pulses', 'Beans', 'Peas',
#        'Pulses, Other and products', 'Treenuts', 'Nuts and products',
#        'Oilcrops', 'Soyabeans', 'Groundnuts (Shelled Eq)',
#        'Sunflower seed', 'Rape and Mustardseed', 'Cottonseed',
#        'Coconuts - Incl Copra', 'Sesame seed',
#        'Olives (including preserved)', 'Oilcrops, Other',
#        'Vegetable Oils', 'Soyabean Oil', 'Groundnut Oil',
# ...

# %%
wine_data = food[food['Item'] == 'Wine']
sum_wine_2015 = wine_data['Y2015'].sum()
sum_wine_2018 = wine_data['Y2018'].sum()
print(f"sum_wine_2015={sum_wine_2015},sum_wine_2018={sum_wine_2018}")
# Out:
# sum_wine_2015=4251.8099999999995,sum_wine_2018=4039.3199999999997

# %%
food.shape
# Out:
# (60943, 12)

# %%
pd.length(food)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-65aca518ec43> in <cell line: 1>()
# ----> 1 pd.length(food)
#
# AttributeError: module 'pandas' has no attribute 'length'

# %%
len(food)
# Out:
# 60943

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
#type error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-ce1543b3be47> in <cell line: 3>()
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age', 'Nationality', 'Overall']
pd.DataFrame(lst, columns = ['Age','Nationality','Overall'],index=[1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
pd.DataFrame(lst, columns = col,index=[i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
pd.DataFrame(lst, columns = col,index=[1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
pd.DataFrame(lst, columns = ['Age','Nationality','Overall'],index=[1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
selected_columns1 = ['Element Code', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']
selected_data2 = food[selected_columns1]
correlations = selected_data2.corr().iloc[0, 1:]
least_correlated_year = correlations.idxmin()
least_correlated_year
# Out:
# 'Y2016'

# %%
selected_data3 = food[['Area', 'Y2017']]
sum_2017_area = selected_data3.groupby('Area')['Y2017'].sum()
seventh_lowest_area = sum_2017_area.sort_values().index[6]
seventh_lowest_area
# Out:
# 'Guinea-Bissau'

# %%
selected_columns2 = ['Element', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']
selected_data4 = food[selected_columns2]
stock_variation_data = selected_data4[selected_data4['Element'] == 'Stock Variation']
stock_variation_data = stock_variation_data.drop(columns=['Element'])
sum_by_year = stock_variation_data.sum()
year_highest_sum = sum_by_year.idxmax()
year_highest_sum
# Out:
# 'Y2014'

# %%
array = ([[94, 89, 63], [93, 92, 48], [92, 94, 56]])
array_df=pd.DataFrame(array,columns=['1','2','3'],index=[1,2,3])
array_df
# Out:
#     1   2   3
# 1  94  89  63
# 2  93  92  48
# 3  92  94  56

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-da159b13dca0> in <cell line: 1>()
# ----> 1 array[:2,0:]
#
# TypeError: list indices must be integers or slices, not tuple
